# %% [markdown]
# <a href="https://colab.research.google.com/github/NVTruong473/DIP/blob/main/yolo-traffic-safety/END_DIP/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # END_DIP — Traffic Safety Monitoring (DIP + YOLO)
# Run top-to-bottom in Google Colab. Enable a GPU first.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf /content/DIP
# !git clone -b feature/yolo-traffic-safety https://github.com/NVTruong473/DIP.git /content/DIP
# %cd /content/DIP/END_DIP
# Out:
# Cloning into '/content/DIP'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 50 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 996.62 KiB | 21.20 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/DIP/END_DIP

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.8/302.8 kB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 66.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 116.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 5.0 MB/s eta 0:00:00

# %%
import os, torch
VIDEO='/content/drive/MyDrive/DIP/video1.mp4'
print('GPU:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')
print('Video exists:', os.path.exists(VIDEO), VIDEO)
assert os.path.exists(VIDEO), 'Put video1.mp4 in MyDrive/DIP first.'
# Out:
# GPU: Tesla T4
# Video exists: True /content/drive/MyDrive/DIP/video1.mp4

# %%
# !python download_models.py --models-dir '/content/drive/MyDrive/DIP/models'
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# vtsr.torchscript: downloading bytes:  51% 3.26M/6.43M [00:04<00:01, 2.54MB/s,  144kB/s  ]
# vtsr.torchscript: downloading bytes: 100% 6.25M/6.25M [00:04<00:00, 1.42MB/s,  557kB/s  ]
# vtsr.torchscript: reconstructing file: 100% 6.43M/6.43M [00:04<00:00, 1.46MB/s,  580kB/s  ]
# Traffic sign: /content/drive/MyDrive/DIP/models/vtsr.torchscript
# label-mapping.json: 100% 2.77k/2.77k [00:00<00:00, 788kB/s]
# Sign mapping: /content/drive/MyDrive/DIP/models/label-mapping.json
#
# yolo11n.pt: downloading bytes:  97% 5.45M/5.61M [00:01<00:00, 4.32MB/s,  151kB/s  ]
# yolo11n.pt: downloading bytes: 100% 5.45M/5.45M [00:01<00:00, 3.37MB/s,  525kB/s  ]
# yolo11n.pt: reconstructing file: 100% 5.61M/5.61M [00:01<00:00, 3.47MB/s,  542kB/s  ]
# Scene: /content/drive/MyDrive/DIP/models/yolo11n.pt
#
# yolov11s(80 epochs).pt: downloading bytes:  99% 19.0M/19.2M [00:01<00:00, 17.5MB/s,  978kB/s  ]
# yolov11s(80 epochs).pt: downloading bytes: 100% 19.0M/19.0M [00:01<00:00, 11.1MB/s, 1.83MB/s  ]
# yolov11s(80 epochs).pt: reconstructing file: 100% 19.2M/19.2M [00:01<00:00, 11.2MB/s, 1.84MB/s  ]
# Helmet: /content/drive/MyDrive/DIP/models/yolov11s(80 epochs).pt

# %% [markdown]
# ## Process the default Drive video
# Outputs are persistent under `MyDrive/DIP/outputs/`.

# %%
# !python main.py \
  --input '/content/drive/MyDrive/DIP/video1.mp4' \
  --output-dir '/content/drive/MyDrive/DIP/outputs' \
  --models-dir '/content/drive/MyDrive/DIP/models'
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# Configuration:
# {
#   "input": "/content/drive/MyDrive/DIP/video1.mp4",
#   "output_dir": "/content/drive/MyDrive/DIP/outputs",
#   "models_dir": "/content/drive/MyDrive/DIP/models",
#   "roi": [
#     [
#       0.48,
#       0.36
#     ],
#     [
#       1.0,
#       0.36
#     ],
#     [
#       1.0,
#       1.0
#     ],
#     [
#       0.38,
#       1.0
#     ]
#   ],
#   "sign_conf": 0.25,
#   "helmet_conf": 0.35
# }
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Processing video:   0% 0/3087 [00:00<?, ?frame/s]Loading /content/drive/MyDrive/DIP/models/vtsr.torchscript for TorchScript inference...
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Using Python 3.13.15 environment at: /usr
# Resolved 2 packages in 295ms
# Prepared 1 package in 41ms
# Installed 1 package in 2ms
#  + lap==0.5.13
#
# requirements: AutoUpdate success ✅ 0.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# Processing video: 100% 3087/3087 [04:48<00:00, 10.68frame/s]

# %%
from IPython.display import Video, display
out='/content/drive/MyDrive/DIP/outputs/video1_result.mp4'
display(Video(out, embed=False, width=900))

# %% [markdown]
# ## Optional: Gradio UI for another video
# Run this cell, then open the public Gradio link and upload any replacement video.

# %%
# !python app.py

# %% [markdown]
# ## Optional fine-tuning
# Only run this if you want a custom `helmet_best.pt`; normal inference already works with the public pretrained checkpoint.

# %%
# import os
# os.environ['ROBOFLOW_API_KEY'] = 'YOUR_KEY'
# !python training/prepare_roboflow_dataset.py --target '/content/drive/MyDrive/DIP/datasets/helmet_rf_v5'
# !python training/train_helmet.py --data '/content/drive/MyDrive/DIP/datasets/helmet_rf_v5/data_helmet_2class.yaml' --models-dir '/content/drive/MyDrive/DIP/models' --runs-dir '/content/drive/MyDrive/DIP/training_runs' --epochs 20 --batch 16
